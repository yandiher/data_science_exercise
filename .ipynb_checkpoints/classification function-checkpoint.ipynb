# %%
def model_comparison(x, y):
    from sklearn.ensemble import RandomForestClassifier
    from sklearn.tree import DecisionTreeClassifier
    from sklearn.neighbors import KNeighborsClassifier
    from sklearn.svm import SVC
    from sklearn.naive_bayes import GaussianNB
    from sklearn.linear_model import LogisticRegression
    from sklearn.linear_model import SGDClassifier
    from sklearn.metrics import accuracy_score
    from sklearn.preprocessing import StandardScaler
    from sklearn.model_selection import train_test_split
    
    scale = StandardScaler()
    x_transform = scale.fit_transform(x)
    x = x_transform
    
    x_train, x_test, y_train, y_test = train_test_split(x, y, train_size=0.8, random_state=42)
    
    models = [RandomForestClassifier,
              DecisionTreeClassifier,
              KNeighborsClassifier, 
              SVC,
              GaussianNB, 
              LogisticRegression, 
              SGDClassifier]
    
    names = ['RandomForestClassifier', 
             'DecisionTreeClassifier', 
             'KNeighborsClassifier', 
             'SVC', 
             'GaussianNB', 
             'LogisticRegression', 
             'SGDClassifier']
    
    scores = []
    
    for m in models:
        model = m()
        model.fit(x_train, y_train)
        y_pred = model.predict(x_test)
        score = accuracy_score(y_test, y_pred)
        scores.append(score)
        
    result = pd.DataFrame({'Name':names, 'Score':scores})
    return result

# %%
import pandas as pd
data = pd.read_csv('data\\glass_data.csv')

# %%
x = data.drop(['Id', 'Type'], axis=1)
y = data['Type']

# %%
tes = model_comparison(x, y)
print(tes)
# Out:
#                      Name     Score
# 0  RandomForestClassifier  0.837209
# 1  DecisionTreeClassifier  0.744186
# 2    KNeighborsClassifier  0.697674
# 3                     SVC  0.720930
# 4              GaussianNB  0.558140
# 5      LogisticRegression  0.720930
# 6           SGDClassifier  0.674419

# %%
def model_comparison(x, y, scale=True):
    from sklearn.ensemble import RandomForestClassifier
    from sklearn.tree import DecisionTreeClassifier
    from sklearn.neighbors import KNeighborsClassifier
    from sklearn.svm import SVC
    from sklearn.naive_bayes import GaussianNB
    from sklearn.linear_model import LogisticRegression
    from sklearn.linear_model import SGDClassifier
    from sklearn.metrics import accuracy_score
    from sklearn.preprocessing import StandardScaler
    from sklearn.model_selection import train_test_split
    
    if scale == True:
        scale = StandardScaler()
        x_transform = scale.fit_transform(x)
        x = x_transform
    
        x_train, x_test, y_train, y_test = train_test_split(x, y, train_size=0.8, random_state=42)
    
        models = [RandomForestClassifier,
                  DecisionTreeClassifier,
                  KNeighborsClassifier,
                  SVC,
                  GaussianNB,
                  LogisticRegression,
                  SGDClassifier]
    
        names = ['RandomForestClassifier', 
                 'DecisionTreeClassifier', 
                 'KNeighborsClassifier',
                 'SVC',
                 'GaussianNB',
                 'LogisticRegression',
                 'SGDClassifier']
    
        scores = []
    
        for m in models:
            model = m()
            model.fit(x_train, y_train)
            y_pred = model.predict(x_test)
            score = accuracy_score(y_test, y_pred)
            scores.append(score)
        
        result = pd.DataFrame({'Name':names, 'Score':scores})
        return result
    
    else:
        x_train, x_test, y_train, y_test = train_test_split(x, y, train_size=0.8, random_state=42)
    
        models = [RandomForestClassifier,
                  DecisionTreeClassifier,
                  KNeighborsClassifier,
                  SVC,
                  GaussianNB,
                  LogisticRegression,
                  SGDClassifier]
    
        names = ['RandomForestClassifier', 
                 'DecisionTreeClassifier', 
                 'KNeighborsClassifier',
                 'SVC',
                 'GaussianNB',
                 'LogisticRegression',
                 'SGDClassifier']
    
        scores = []
    
        for m in models:
            model = m()
            model.fit(x_train, y_train)
            y_pred = model.predict(x_test)
            score = accuracy_score(y_test, y_pred)
            scores.append(score)
        
        result = pd.DataFrame({'Name':names, 'Score':scores})
        return result

# %%
percobaan = model_comparison(x, y, scale=False)
percobaan
# Out:
# C:\Users\yandiher\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#                      Name     Score
# 0  RandomForestClassifier  0.860465
# 1  DecisionTreeClassifier  0.790698
# 2    KNeighborsClassifier  0.651163
# 3                     SVC  0.325581
# 4              GaussianNB  0.558140
# 5      LogisticRegression  0.720930
# 6           SGDClassifier  0.418605

# %%
percobaan = model_comparison(x, y, scale=True)
percobaan
# Out:
#                      Name     Score
# 0  RandomForestClassifier  0.837209
# 1  DecisionTreeClassifier  0.744186
# 2    KNeighborsClassifier  0.697674
# 3                     SVC  0.720930
# 4              GaussianNB  0.558140
# 5      LogisticRegression  0.720930
# 6           SGDClassifier  0.627907
